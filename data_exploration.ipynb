# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("data/data.csv")
data = data.drop(columns=["Id"])
data.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9        NaN
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                   NaN   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                  NaN                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %% [markdown]
# ### for each column I randomly chose 5% of the records and replaced the value with NaN because the dataset did not have missing values

# %%
data.isna().sum()
# Out:
# fixed acidity           63
# volatile acidity        50
# citric acid             60
# residual sugar          49
# chlorides               58
# free sulfur dioxide     59
# total sulfur dioxide    60
# density                 57
# pH                      52
# sulphates               71
# alcohol                 47
# quality                  0
# dtype: int64

# %%
data.hist(bins=20, figsize=(15, 10))
plt.show()

# %%
plt.figure(figsize=(10,10))
sns.heatmap(data.corr(), annot=True, cmap="RdYlGn")
plt.show()

# %%
'''
conclusions:

- not many outliers and their values aren't that much different from the mean
- although ratings from 0 to 10 are possible, there are only ratings from 3 to 8
  and only ratings 5, 6 and 7 are present in a meaningful way
'''
